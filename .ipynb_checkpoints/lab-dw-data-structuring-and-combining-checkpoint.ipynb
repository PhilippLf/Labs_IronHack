# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# # Challenge 1: Combining Data

# %% [markdown]
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the following links:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2_clean.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3_clean.csv
#
# Combine the data from the three dataframes into a single dataframe, named "customer_data", using appropriate merging, concatenating, and joining techniques.
#
# Verify that the customer_data dataframe contains all the rows and columns from the three original dataframes.

# %% [markdown]
# ## Alternative - Bonus
#
# If in the previous lab you created your cleaning and formatting function, or if you want to do it now, instead of using the two clean files provided above, you can use your function to clean and format the data in these two raw files, and work with your clean files instead:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd
import numpy as np

# %%
df1_uncleaned = pd.read_csv('file1.csv')

# %%
df1_uncleaned.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
df1_uncleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   ST                         1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB

# %%
df2_uncleaned = pd.read_csv('file2.csv')

# %%
df2_uncleaned.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
df2_uncleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   996 non-null    object
#  1   ST                         996 non-null    object
#  2   GENDER                     991 non-null    object
#  3   Education                  996 non-null    object
#  4   Customer Lifetime Value    992 non-null    object
#  5   Income                     996 non-null    int64
#  6   Monthly Premium Auto       996 non-null    int64
#  7   Number of Open Complaints  996 non-null    object
#  8   Total Claim Amount         996 non-null    float64
#  9   Policy Type                996 non-null    object
#  10  Vehicle Class              996 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 85.7+ KB

# %%
df2_uncleaned['GENDER'].unique()
# Out:
# array(['F', 'M', nan, 'female', 'Male'], dtype=object)

# %%
df2_uncleaned['ST'].unique()
# Out:
# array(['Arizona', 'California', 'Oregon', 'Nevada', 'Washington', 'AZ'],
#       dtype=object)

# %%
df2_uncleaned['Education'].unique()
# Out:
# array(['Bachelor', 'Master', 'College', 'Doctor', 'Bachelors',
#        'High School or Below'], dtype=object)

# %%
#df2_uncleaned['Customer Lifetime Value'].unique()

# %%
df2_uncleaned['Vehicle Class'].unique()
# Out:
# array(['Four-Door Car', 'SUV', 'Two-Door Car', 'Luxury Car', 'Sports Car',
#        'Luxury SUV'], dtype=object)

# %%
df3_uncleaned = pd.read_csv('file3.csv')

# %%
df3_uncleaned.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
df3_uncleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   7070 non-null   object
#  1   State                      7070 non-null   object
#  2   Customer Lifetime Value    7070 non-null   float64
#  3   Education                  7070 non-null   object
#  4   Gender                     7070 non-null   object
#  5   Income                     7070 non-null   int64
#  6   Monthly Premium Auto       7070 non-null   int64
#  7   Number of Open Complaints  7070 non-null   int64
#  8   Policy Type                7070 non-null   object
#  9   Total Claim Amount         7070 non-null   float64
#  10  Vehicle Class              7070 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB

# %%
df3_uncleaned['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df3_uncleaned['State'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon'],
#       dtype=object)

# %%
df3_uncleaned['Education'].unique()
# Out:
# array(['High School or Below', 'Master', 'Bachelor', 'College', 'Doctor'],
#       dtype=object)

# %%
df3_uncleaned['Customer Lifetime Value'].unique()
# Out:
# array([3479.137523, 2502.637401, 3265.156348, ..., 8163.890428,
#        7524.442436, 2611.836866])

# %%
df3_uncleaned['Vehicle Class'].unique()
# Out:
# array(['Two-Door Car', 'Four-Door Car', 'SUV', 'Sports Car', 'Luxury SUV',
#        'Luxury Car'], dtype=object)

# %%
# CLEANING FUNCTIONS

def clean_gender(x):
    if x in ['M', 'Male']:
        return 'M'
    elif x in ['F','female','Femal']:
        return 'F'
    else:
        return x
    
def clean_state(x):
    if x in ['Washington', 'WA']:
        return 'Washington'
    elif x in ['Arizona', 'AZ']:
        return 'Arizona'
    elif x in ['California', 'Cali']:
        return 'California'
    else:
        return x    

def clean_data(df):
    
    df.columns=[i.lower() for i in df.columns]
    
    df.columns=[i.replace(' ', '_') for i in df.columns]
    
    df.rename(columns={'st':'state'}, inplace=True)
    
    df['gender'] = df['gender'].apply(clean_gender)
    
    df.replace({'education':'Bachelors'}, 'Bachelor', inplace=True)
    
    try:
        df['customer_lifetime_value'] = df['customer_lifetime_value'].str.replace('%', '')
    except:
        df['customer_lifetime_value'] = df['customer_lifetime_value']
    
    df.replace({'vehicle_class':{'Luxury SUV':'Luxury Car','Sports Car':'Luxury Car'}}, inplace=True)
    
    df['customer_lifetime_value'] = df['customer_lifetime_value'].astype('float')
    
    df['number_of_open_complaints'] = df['number_of_open_complaints'].apply(lambda x: float(x.split('/')[1]) if type(x) == str else x)
    
    df.dropna(how='all', inplace=True)
    
    df['gender'] = df['gender'].fillna('U')
    
    df['customer_lifetime_value'] = df['customer_lifetime_value'].fillna(np.round(df['customer_lifetime_value'].mean(),2))
    
    df['income'] = df['income'].astype('float')
    
    df['monthly_premium_auto'] = df['monthly_premium_auto'].astype('float')
    
    df['number_of_open_complaints'] = df['number_of_open_complaints'].astype('float')
    
    df['total_claim_amount'] = df['total_claim_amount'].astype('float')
    
    df = df.reindex(columns=['customer','state','gender','education','customer_lifetime_value','income','monthly_premium_auto','number_of_open_complaints','policy_type','vehicle_class','total_claim_amount'])
    
    return df

# %%
df1_cleaned = clean_data(df1_uncleaned)

# %%
df1_cleaned.head()
# Out:
#   customer       state gender             education  customer_lifetime_value  \
# 0  RB50392  Washington      U                Master                793690.26
# 1  QZ44356     Arizona      F              Bachelor                697953.59
# 2  AI49188      Nevada      F              Bachelor               1288743.17
# 3  WW63253  California      M              Bachelor                764586.18
# 4  GA49547  Washington      M  High School or Below                536307.65
#
#     income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                        0.0   Personal Auto
# 1      0.0                  94.0                        0.0   Personal Auto
# 2  48767.0                 108.0                        0.0   Personal Auto
# 3      0.0                 106.0                        0.0  Corporate Auto
# 4  36357.0                  68.0                        0.0   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
df1_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1071 entries, 0 to 1070
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   1071 non-null   object
#  1   state                      1071 non-null   object
#  2   gender                     1071 non-null   object
#  3   education                  1071 non-null   object
#  4   customer_lifetime_value    1071 non-null   float64
#  5   income                     1071 non-null   float64
#  6   monthly_premium_auto       1071 non-null   float64
#  7   number_of_open_complaints  1071 non-null   float64
#  8   policy_type                1071 non-null   object
#  9   vehicle_class              1071 non-null   object
#  10  total_claim_amount         1071 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 100.4+ KB

# %%
df1_cleaned.isna().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# policy_type                  0
# vehicle_class                0
# total_claim_amount           0
# dtype: int64

# %%
df_duplicates = df1_cleaned[df1_cleaned.duplicated()]
df_duplicates
# Out:
# Empty DataFrame
# Columns: [customer, state, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, policy_type, vehicle_class, total_claim_amount]
# Index: []

# %%
df2_cleaned = clean_data(df2_uncleaned)

# %%
df2_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   996 non-null    object
#  1   state                      996 non-null    object
#  2   gender                     996 non-null    object
#  3   education                  996 non-null    object
#  4   customer_lifetime_value    996 non-null    float64
#  5   income                     996 non-null    float64
#  6   monthly_premium_auto       996 non-null    float64
#  7   number_of_open_complaints  996 non-null    float64
#  8   policy_type                996 non-null    object
#  9   vehicle_class              996 non-null    object
#  10  total_claim_amount         996 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 85.7+ KB

# %%
df2_cleaned.head()
# Out:
#   customer       state gender education  customer_lifetime_value   income  \
# 0  GS98873     Arizona      F  Bachelor                323912.47  16061.0
# 1  CW49887  California      F    Master                462680.11  79487.0
# 2  MY31220  California      F   College                899704.02  54230.0
# 3  UH35128      Oregon      F   College               2580706.30  71210.0
# 4  WH52799     Arizona      F   College                380812.21  94903.0
#
#    monthly_premium_auto  number_of_open_complaints     policy_type  \
# 0                  88.0                        0.0   Personal Auto
# 1                 114.0                        0.0    Special Auto
# 2                 112.0                        0.0   Personal Auto
# 3                 214.0                        1.0   Personal Auto
# 4                  94.0                        0.0  Corporate Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# ...

# %%
df2_cleaned.isna().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# policy_type                  0
# vehicle_class                0
# total_claim_amount           0
# dtype: int64

# %%
df_duplicates = df2_cleaned[df2_cleaned.duplicated()]
df_duplicates
# Out:
# Empty DataFrame
# Columns: [customer, state, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, policy_type, vehicle_class, total_claim_amount]
# Index: []

# %%
df3_cleaned = clean_data(df3_uncleaned)

# %%
df3_cleaned.head()
# Out:
#   customer       state gender             education  customer_lifetime_value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#     income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0      0.0                 104.0                        0.0  Personal Auto
# 1      0.0                  66.0                        0.0  Personal Auto
# 2  25820.0                  82.0                        0.0  Personal Auto
# 3      0.0                 121.0                        0.0  Personal Auto
# 4  30366.0                 101.0                        2.0  Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
df3_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   7070 non-null   object
#  1   state                      7070 non-null   object
#  2   gender                     7070 non-null   object
#  3   education                  7070 non-null   object
#  4   customer_lifetime_value    7070 non-null   float64
#  5   income                     7070 non-null   float64
#  6   monthly_premium_auto       7070 non-null   float64
#  7   number_of_open_complaints  7070 non-null   float64
#  8   policy_type                7070 non-null   object
#  9   vehicle_class              7070 non-null   object
#  10  total_claim_amount         7070 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 607.7+ KB

# %%
df3_cleaned.isna().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# policy_type                  0
# vehicle_class                0
# total_claim_amount           0
# dtype: int64

# %%
df_duplicates = df3_cleaned[df3_cleaned.duplicated()]
df_duplicates
# Out:
# Empty DataFrame
# Columns: [customer, state, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, policy_type, vehicle_class, total_claim_amount]
# Index: []

# %%
df = pd.concat([df1_cleaned, df2_cleaned, df3_cleaned])

# %%
df.head()
# Out:
#   customer       state gender             education  customer_lifetime_value  \
# 0  RB50392  Washington      U                Master                793690.26
# 1  QZ44356     Arizona      F              Bachelor                697953.59
# 2  AI49188      Nevada      F              Bachelor               1288743.17
# 3  WW63253  California      M              Bachelor                764586.18
# 4  GA49547  Washington      M  High School or Below                536307.65
#
#     income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                        0.0   Personal Auto
# 1      0.0                  94.0                        0.0   Personal Auto
# 2  48767.0                 108.0                        0.0   Personal Auto
# 3      0.0                 106.0                        0.0  Corporate Auto
# 4  36357.0                  68.0                        0.0   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
df.tail()
# Out:
#      customer       state gender education  customer_lifetime_value   income  \
# 7065  LA72316  California      M  Bachelor             23405.987980  71941.0
# 7066  PK87824  California      F   College              3096.511217  21604.0
# 7067  TD14365  California      M  Bachelor              8163.890428      0.0
# 7068  UP19263  California      M   College              7524.442436  21941.0
# 7069  Y167826  California      M   College              2611.836866      0.0
#
#       monthly_premium_auto  number_of_open_complaints     policy_type  \
# 7065                  73.0                        0.0   Personal Auto
# 7066                  79.0                        0.0  Corporate Auto
# 7067                  85.0                        3.0  Corporate Auto
# 7068                  96.0                        0.0   Personal Auto
# 7069                  77.0                        0.0  Corporate Auto
#
#       vehicle_class  total_claim_amount
# 7065  Four-Door Car          198.234764
# ...

# %%
df_duplicates = df[df.duplicated()]
df_duplicates
# Out:
#   customer       state gender education  customer_lifetime_value   income  \
# 0  GS98873     Arizona      F  Bachelor                323912.47  16061.0
# 1  CW49887  California      F    Master                462680.11  79487.0
# 2  MY31220  California      F   College                899704.02  54230.0
#
#    monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0                  88.0                        0.0  Personal Auto
# 1                 114.0                        0.0   Special Auto
# 2                 112.0                        0.0  Personal Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# 2   Two-Door Car               537.6

# %%
df.drop_duplicates(inplace=True)

# %%
df_duplicates = df[df.duplicated()]
df_duplicates
# Out:
# Empty DataFrame
# Columns: [customer, state, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, policy_type, vehicle_class, total_claim_amount]
# Index: []

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
df_raw = pd.read_csv('marketing_customer_analysis_clean.csv')

# %%
df_raw = df_raw.drop('unnamed:_0', axis=1)

# %%
df_raw.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %%
df_raw.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ... number_of_policies  \
# 0        2011-02-18         Employed      M   48029  ...                  9
# 1        2011-01-18       Unemployed      F       0  ...                  1
# 2        2011-02-10         Employed      M   22139  ...                  2
# 3        2011-01-11         Employed      M   49078  ...                  2
# 4        2011-01-17    Medical Leave      F   23675  ...                  7
#
# ...

# %%
df_raw['vehicle_class']
# Out:
# 0        Four-Door Car
# 1        Four-Door Car
# 2                  SUV
# 3        Four-Door Car
# 4        Four-Door Car
#              ...
# 10905       Luxury Car
# 10906    Four-Door Car
# 10907       Luxury SUV
# 10908              SUV
# 10909              SUV
# Name: vehicle_class, Length: 10910, dtype: object

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10910 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10910 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %%
df_raw.isna().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# month                            0
# dtype: int64

# %%
df_raw['sales_channel'].unique()
# Out:
# array(['Agent', 'Call Center', 'Branch', 'Web'], dtype=object)

# %%
df_raw['total_revenue'] = df_raw[['monthly_premium_auto','month']].apply(lambda x: x['monthly_premium_auto']*2 if x['month'] == 1 else x['monthly_premium_auto'], axis=1)

# %%
df_raw[['monthly_premium_auto', 'month', 'total_revenue']]
# Out:
#        monthly_premium_auto  month  total_revenue
# 0                        61      2             61
# 1                        64      1            128
# 2                       100      2            100
# 3                        97      1            194
# 4                       117      1            234
# ...                     ...    ...            ...
# 10905                   253      1            506
# 10906                    65      1            130
# 10907                   201      2            201
# 10908                   158      2            158
# 10909                   101      1            202
#
# [10910 rows x 3 columns]

# %%
df_raw
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
df_raw
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
np.round(df_raw.pivot_table(index='sales_channel',values='total_revenue', aggfunc= 'sum'),2)
# Out:
#                total_revenue
# sales_channel
# Agent                 589213
# Branch                432919
# Call Center           302323
# Web                   233169

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
df_raw.pivot_table(index=['gender','education'],values='customer_lifetime_value')
# Out:
#                              customer_lifetime_value
# gender education
# F      Bachelor                          7874.269478
#        College                           7748.823325
#        Doctor                            7328.508916
#        High School or Below              8675.220201
#        Master                            8157.053154
# M      Bachelor                          7703.601675
#        College                           8052.459288
#        Doctor                            7415.333638
#        High School or Below              8149.687783
#        Master                            8168.832659

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
df_raw.pivot_table(index=['policy_type','month'],values='number_of_open_complaints',aggfunc='sum')
# Out:
#                       number_of_open_complaints
# policy_type    month
# Corporate Auto 1                     443.434952
#                2                     385.208135
# Personal Auto  1                    1727.605722
#                2                    1453.684441
# Special Auto   1                      87.074049
#                2                      95.226817
